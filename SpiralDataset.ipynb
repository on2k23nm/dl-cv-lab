# %%
! pip install -q torchmetrics

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
from torchmetrics.classification import MulticlassAccuracy

import torch
from torch import nn

import numpy as np

# %% [markdown]
# # 1. Create a dataset

# %%
N = 1000 # number of points per class
D = 2 # dimensionality
K = 4 # number of classes

X_np = np.zeros((N*K,D)) # data matrix (each row = single example)
y_np = np.zeros(N*K, dtype='uint8') # class labels

for j in range(K):
  ix = range(N*j,N*(j+1))
  r = np.linspace(0.0,1,N) # radius
  t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.15 # theta
  X_np[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
  y_np[ix] = j
  
# lets visualize the data:
plt.figure(figsize=(10, 7))
plt.scatter(X_np[:,0], X_np[:,1], c=y_np, marker='o', cmap=plt.cm.Dark2)
plt.title("Dataset")
plt.show()

# %% [markdown]
# # 2. Convert the numpy data to PyTorch tensors

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

X_t = torch.from_numpy(X_np).to(device=device, dtype=torch.float32)
y_t = torch.from_numpy(y_np).to(device=device, dtype=torch.float32)

X_t.shape, y_t.shape
# Out:
# (torch.Size([4000, 2]), torch.Size([4000]))

# %% [markdown]
# # 3. Create a train, val, test set

# %%
N = X_t.shape[0]

g = torch.Generator(device=device).manual_seed(42)
indices = torch.randperm(N, generator=g, device=device)

ratios = [0.7, 0.2, 0.1]
train, val, _ = (int(x * N) for x in ratios)

train_indices = indices[:train]
val_indices = indices[train:train+val]
test_indices = indices[train+val:]

X_train, y_train = X_t[train_indices], y_t[train_indices]
X_val, y_val = X_t[val_indices], y_t[val_indices]
X_test, y_test = X_t[test_indices], y_t[test_indices]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape

y_train.dtype
# Out:
# torch.float32

# %% [markdown]
# # 4. Define a model

# %%
class SpiralDataset(nn.Module):
    def __init__(self, in_features, out_features, hiddlen_layers=4):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_features, hiddlen_layers),
            nn.ReLU(),
            nn.Linear(hiddlen_layers, hiddlen_layers),
            nn.ReLU(),
            nn.Linear(hiddlen_layers, hiddlen_layers),
            nn.ReLU(),
            nn.Linear(hiddlen_layers, out_features)
        )
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# # 5. Create loss metrics function

# %%
from torchmetrics.classification import MulticlassAccuracy

# def get_loss_metrics(y_logits, y_train):
#     acc_metrics = MulticlassAccuracy(num_classes=n_classes).to(device=device)
#     batch_acc = acc_metrics(y_logits, y_train)
#     return batch_acc

def get_loss_metrics(y_logits, y_train):
    y_ = torch.softmax(y_logits, dim=1)
    y_preds = torch.argmax(y_, dim=1).float()
    acc = y_preds.view_as(y_train).eq(y_train).float().mean()
    return acc

# %% [markdown]
# # 6. Create a training loop

# %%
def train_one_epoch(model, optimizer, loss_fn, X_train, y_train):
    model.train()
    optimizer.zero_grad(set_to_none=True)
    
    y_logits = model(X_train)
    loss = loss_fn(y_logits, y_train.long())
    loss.backward()
    optimizer.step()
    
    with torch.no_grad():
        acc = get_loss_metrics(y_logits, y_train)
    return loss.item(), acc.item() * 100

def validate_one_epoch(model, loss_fn, X_val, y_val):
    model.eval()
    
    with torch.inference_mode():
        y_logits = model(X_val)
        loss = loss_fn(y_logits, y_val.long())
        
        acc = get_loss_metrics(y_logits, y_val)
        
        return loss.item(), acc.item() * 100
    
def fit(model, optimizer, loss_fn, X_train, y_train, X_val, y_val, epochs=50, verbose_every=5):
    history = { "train_loss": [], "train_acc": [], "val_loss": [], "val_acc": [] }
    
    for ep in range(1, epochs+1):
        train_loss, train_acc = train_one_epoch(model, optimizer, loss_fn, X_train, y_train)
        val_loss, val_acc = validate_one_epoch(model, loss_fn, X_val, y_val)
        
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        
        if ep % verbose_every == 0 or ep == 0 or ep == epochs:
            print(f"Epoch: {ep:3d} |"
                  f"Training loss: {train_loss:.4f}, Training Accuracy: {train_acc:6.2f} |"
                  f"Validation loss: {val_loss:.4f}, Validation Accuracy: {val_acc:6.2f}")
    return history

# %% [markdown]
# # 7. Create model instance, define a loss function and optimizer

# %%
n_classes = 4
model = SpiralDataset(in_features=2, out_features=4, hiddlen_layers=128).to(device=device)
model.state_dict()

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # 8. Fit the data

# %%
hist = fit(model, optimizer, loss_fn, X_train, y_train, X_val, y_val, epochs=300)
# Out:
# Epoch:   5 |Training loss: 1.3402, Training Accuracy:  42.04 |Validation loss: 1.3281, Validation Accuracy:  43.38
# Epoch:  10 |Training loss: 1.2821, Training Accuracy:  40.71 |Validation loss: 1.2628, Validation Accuracy:  43.00
# Epoch:  15 |Training loss: 1.2033, Training Accuracy:  41.89 |Validation loss: 1.1748, Validation Accuracy:  42.75
# Epoch:  20 |Training loss: 1.1108, Training Accuracy:  42.39 |Validation loss: 1.0761, Validation Accuracy:  43.87
# Epoch:  25 |Training loss: 1.0269, Training Accuracy:  42.89 |Validation loss: 0.9922, Validation Accuracy:  45.12
# Epoch:  30 |Training loss: 0.9674, Training Accuracy:  43.93 |Validation loss: 0.9346, Validation Accuracy:  46.00
# Epoch:  35 |Training loss: 0.9218, Training Accuracy:  45.79 |Validation loss: 0.8883, Validation Accuracy:  48.25
# Epoch:  40 |Training loss: 0.8736, Training Accuracy:  48.57 |Validation loss: 0.8395, Validation Accuracy:  51.38
# Epoch:  45 |Training loss: 0.8177, Training Accuracy:  53.39 |Validation loss: 0.7858, Validation Accuracy:  55.50
# Epoch:  50 |Training loss: 0.7573, Training Accuracy:  59.29 |Validation loss: 0.7297, Validation Accuracy:  60.62
# Epoch:  55 |Training loss: 0.6949, Training Accuracy:  64.39 |Validation loss: 0.6716, Validation Accuracy:  64.63
# Epoch:  60 |Training loss: 0.6323, Training Accuracy:  70.21 |Validation loss: 0.6123, Validation Accuracy:  70.13
# Epoch:  65 |Training loss: 0.5714, Training Accuracy:  75.00 |Validation loss: 0.5546, Validation Accuracy:  74.87
# Epoch:  70 |Training loss: 0.5148, Training Accuracy:  79.11 |Validation loss: 0.5009, Validation Accuracy:  79.25
# Epoch:  75 |Training loss: 0.4637, Training Accuracy:  83.71 |Validation loss: 0.4528, Validation Accuracy:  83.75
# Epoch:  80 |Training loss: 0.4180, Training Accuracy:  86.50 |Validation loss: 0.4098, Validation Accuracy:  86.62
# Epoch:  85 |Training loss: 0.3770, Training Accuracy:  89.29 |Validation loss: 0.3706, Validation Accuracy:  89.63
# Epoch:  90 |Training loss: 0.3392, Training Accuracy:  91.14 |Validation loss: 0.3346, Validation Accuracy:  91.75
# Epoch:  95 |Training loss: 0.3047, Training Accuracy:  92.86 |Validation loss: 0.3010, Validation Accuracy:  92.62
# Epoch: 100 |Training loss: 0.2723, Training Accuracy:  94.21 |Validation loss: 0.2696, Validation Accuracy:  93.62
# Epoch: 105 |Training loss: 0.2429, Training Accuracy:  94.86 |Validation loss: 0.2416, Validation Accuracy:  93.88
# Epoch: 110 |Training loss: 0.2170, Training Accuracy:  95.54 |Validation loss: 0.2171, Validation Accuracy:  94.50
# Epoch: 115 |Training loss: 0.1977, Training Accuracy:  94.54 |Validation loss: 0.1969, Validation Accuracy:  94.63
# Epoch: 120 |Training loss: 0.1780, Training Accuracy:  96.32 |Validation loss: 0.1831, Validation Accuracy:  94.50
# Epoch: 125 |Training loss: 0.1643, Training Accuracy:  96.71 |Validation loss: 0.1680, Validation Accuracy:  95.13
# Epoch: 130 |Training loss: 0.1526, Training Accuracy:  96.71 |Validation loss: 0.1577, Validation Accuracy:  94.88
# Epoch: 135 |Training loss: 0.1425, Training Accuracy:  97.14 |Validation loss: 0.1490, Validation Accuracy:  95.13
# Epoch: 140 |Training loss: 0.1336, Training Accuracy:  97.25 |Validation loss: 0.1409, Validation Accuracy:  95.63
# Epoch: 145 |Training loss: 0.1257, Training Accuracy:  97.46 |Validation loss: 0.1343, Validation Accuracy:  96.13
# Epoch: 150 |Training loss: 0.1191, Training Accuracy:  97.61 |Validation loss: 0.1283, Validation Accuracy:  96.38
# Epoch: 155 |Training loss: 0.1131, Training Accuracy:  97.75 |Validation loss: 0.1228, Validation Accuracy:  96.63
# Epoch: 160 |Training loss: 0.1078, Training Accuracy:  97.86 |Validation loss: 0.1180, Validation Accuracy:  96.88
# Epoch: 165 |Training loss: 0.1030, Training Accuracy:  97.89 |Validation loss: 0.1138, Validation Accuracy:  96.88
# Epoch: 170 |Training loss: 0.0987, Training Accuracy:  97.86 |Validation loss: 0.1100, Validation Accuracy:  96.88
# Epoch: 175 |Training loss: 0.0948, Training Accuracy:  97.93 |Validation loss: 0.1065, Validation Accuracy:  97.00
# Epoch: 180 |Training loss: 0.0913, Training Accuracy:  98.00 |Validation loss: 0.1033, Validation Accuracy:  97.00
# Epoch: 185 |Training loss: 0.0882, Training Accuracy:  97.96 |Validation loss: 0.1004, Validation Accuracy:  97.12
# Epoch: 190 |Training loss: 0.0853, Training Accuracy:  97.96 |Validation loss: 0.0978, Validation Accuracy:  97.12
# Epoch: 195 |Training loss: 0.0826, Training Accuracy:  98.18 |Validation loss: 0.0955, Validation Accuracy:  97.12
# Epoch: 200 |Training loss: 0.0802, Training Accuracy:  98.21 |Validation loss: 0.0935, Validation Accuracy:  97.12
# Epoch: 205 |Training loss: 0.0780, Training Accuracy:  98.21 |Validation loss: 0.0917, Validation Accuracy:  97.25
# Epoch: 210 |Training loss: 0.0759, Training Accuracy:  98.29 |Validation loss: 0.0899, Validation Accuracy:  97.25
# Epoch: 215 |Training loss: 0.0742, Training Accuracy:  98.18 |Validation loss: 0.0886, Validation Accuracy:  97.25
# Epoch: 220 |Training loss: 0.0733, Training Accuracy:  98.29 |Validation loss: 0.0874, Validation Accuracy:  97.25
# Epoch: 225 |Training loss: 0.0712, Training Accuracy:  98.25 |Validation loss: 0.0860, Validation Accuracy:  97.25
# Epoch: 230 |Training loss: 0.0696, Training Accuracy:  98.25 |Validation loss: 0.0847, Validation Accuracy:  97.37
# Epoch: 235 |Training loss: 0.0681, Training Accuracy:  98.39 |Validation loss: 0.0836, Validation Accuracy:  97.37
# Epoch: 240 |Training loss: 0.0668, Training Accuracy:  98.43 |Validation loss: 0.0824, Validation Accuracy:  97.25
# Epoch: 245 |Training loss: 0.0656, Training Accuracy:  98.46 |Validation loss: 0.0813, Validation Accuracy:  97.37
# Epoch: 250 |Training loss: 0.0646, Training Accuracy:  98.46 |Validation loss: 0.0805, Validation Accuracy:  97.37
# Epoch: 255 |Training loss: 0.0635, Training Accuracy:  98.46 |Validation loss: 0.0796, Validation Accuracy:  97.37
# Epoch: 260 |Training loss: 0.0625, Training Accuracy:  98.46 |Validation loss: 0.0788, Validation Accuracy:  97.37
# Epoch: 265 |Training loss: 0.0616, Training Accuracy:  98.50 |Validation loss: 0.0780, Validation Accuracy:  97.37
# Epoch: 270 |Training loss: 0.0606, Training Accuracy:  98.46 |Validation loss: 0.0774, Validation Accuracy:  97.37
# Epoch: 275 |Training loss: 0.0598, Training Accuracy:  98.46 |Validation loss: 0.0767, Validation Accuracy:  97.37
# Epoch: 280 |Training loss: 0.0590, Training Accuracy:  98.46 |Validation loss: 0.0762, Validation Accuracy:  97.37
# Epoch: 285 |Training loss: 0.0583, Training Accuracy:  98.57 |Validation loss: 0.0757, Validation Accuracy:  97.50
# Epoch: 290 |Training loss: 0.0589, Training Accuracy:  98.25 |Validation loss: 0.0762, Validation Accuracy:  97.50
# Epoch: 295 |Training loss: 0.0574, Training Accuracy:  98.36 |Validation loss: 0.0753, Validation Accuracy:  97.50
# Epoch: 300 |Training loss: 0.0565, Training Accuracy:  98.43 |Validation loss: 0.0747, Validation Accuracy:  97.50

# %% [markdown]
# # 9. Plot train loss, acc and validation loss, acc

# %%
def plot_history(history, every=1):
    epochs = np.arange(1, len(history["train_loss"]) + 1)
    
    fig, axes = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)
    
    # -- Training & Validation losses --
    ax = axes[0]
    ax.plot(epochs[::every], history["train_loss"][::every], label="Training loss")
    ax.plot(epochs[::every], history["val_loss"][::every], label="Validation loss")
    ax.set_xlabel("Epochs")
    ax.set_ylabel("Losses")
    ax.set_title("Losses vs. Epoch")
    ax.grid(True)
    ax.legend()

    # -- Training and validation accuracy --
    ax = axes[1]
    ax.plot(epochs[::every], history["train_acc"][::every], label="Training Accuracy")
    ax.plot(epochs[::every], history["val_acc"][::every], label="Validation Accuracy")
    ax.set_xlabel("Epochs")
    ax.set_ylabel("Accuracy")
    ax.set_title("Accuracy vs. Epochs")
    ax.grid(True)
    ax.legend()
    
    plt.show()

# %%
plot_history(hist)

# %% [markdown]
# # 10. Draw a decision boundry

# %%
def plot_multiclass_boundary(model, X_np, y_np, h=0.0025):
    pad = 0.5
    x_min, x_max = X_np[:,0].min()-pad, X_np[:,0].max()+pad
    y_min, y_max = X_np[:,1].min()-pad, X_np[:,1].max()+pad

    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    print(f"xx.shape: {xx.shape}")
    print(f"yy.shape: {yy.shape}")
    grid = np.c_[xx.ravel(), yy.ravel()]
    grid_t = torch.from_numpy(grid).float().to(next(model.parameters()).device)
    print(f"grid_t.shape: {grid_t.shape}")

    model.eval()
    with torch.inference_mode():
        logits = model(grid_t)                   # [Ngrid, C]
        print(f"logits.shape: {logits.shape}")
        preds  = torch.argmax(logits, dim=1)     # class ids
        print(f"preds.shape: {preds.shape}")
        Z = preds.view(xx.shape).cpu().numpy()
        print(f"Z.shape: {Z.shape}")

    plt.figure(figsize=(10,7))
    # Background regions by class
    plt.contourf(xx, yy, Z, levels=25, alpha=0.25, cmap=plt.cm.Dark2)

    # Boundary lines at half-integers between class ids (0|1, 1|2, 2|3, ...)
    print(f"Z.max() : {Z.max()}")
    num_classes = int(Z.max() + 1)
    levels = np.arange(num_classes)
    print(f"levels: {levels}")
    plt.contour(xx, yy, Z, levels=levels, colors='k')

    # Training points
    plt.scatter(X_np[:,0], X_np[:,1], c=y_np, cmap=plt.cm.Dark2)
    plt.title("Multiclass decision boundaries")
    plt.xlabel("x1"); plt.ylabel("x2")
    # plt.gca().set_aspect('equal', 'box')
    plt.show()

# %%
plot_multiclass_boundary(model, X_np, y_np)
# Out:
# xx.shape: (1170, 1148)
# yy.shape: (1170, 1148)
# grid_t.shape: torch.Size([1343160, 2])
# logits.shape: torch.Size([1343160, 4])
# preds.shape: torch.Size([1343160])
# Z.shape: (1170, 1148)
# Z.max() : 3
# levels: [0 1 2 3]

# %% [markdown]
# # 11. Test the data on the testset

# %%
model.eval()
with torch.inference_mode():
    logits = model(X_test)
    p_ = torch.softmax(logits, dim=1)
    preds = torch.argmax(p_, dim=1)
    
    plt.figure(figsize=(10, 7))
    plt.scatter(X_test[:,0].cpu().numpy(), X_test[:,1].cpu().numpy(), c=y_test.cpu().numpy(), marker='o', cmap=plt.cm.Dark2)
    plt.scatter(X_test[:,0].cpu().numpy(), X_test[:,1].cpu().numpy(), c=preds.cpu().numpy(), marker='x', cmap=plt.cm.Dark2)
    
    plt.title("Test Predictions vs. ground truth")
    plt.show()
